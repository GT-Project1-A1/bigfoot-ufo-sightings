# %% [markdown]
# # Extract BigFoot CSV Data

# %% [markdown]
# ### Source:  Data.World.com
# ### URL:  https://data.world/timothyrenner/bfro-sightings-data/workspace/file?filename=bfro_reports_geocoded.csv

# %%
# Use pandas and SQLAlchemy to extract data
import pandas as pd
from sqlalchemy import create_engine

# %%
# Establish path for extracting BigFoot csv file
csv_path = "Resources/bfro_reports_geocoded.csv"

# %%
# Extract BigFoot csv data into pandas dataframe using above path
bf_df = pd.read_csv(csv_path)
bf_df.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  For the past four years my family has seen a c...
# 2  This happened to me when I was 13 in upstate S...
# 3  While attending U.R.I in the Fall of 1974,I wo...
# 4  Hello, My name is Doug and though I am very re...
#
#                                     location_details  \
# 0                  East side of Prince William Sound
# 1  This location is near the junction of Bureau o...
# 2  York South Carolina at Walnut Farm, Piedmont A...
# 3             Great swamp area, Narragansett Indians
# 4  I would rather not have exact location (listin...
#
#                            county           state  season  \
# 0  Valdez-Chitina-Whittier County          Alaska    Fall
# 1                  Shannon County    South Dakota    Fall
# 2                     York County  South Carolina    Fall
# 3               Washington County    Rhode Island    Fall
# ...
