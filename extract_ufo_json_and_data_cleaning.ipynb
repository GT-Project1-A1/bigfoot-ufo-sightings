# %% [markdown]
# # Extract UFO JSON Data

# %% [markdown]
# ### Source: Data.World.com
# ### URL: https://data.world/timothyrenner/ufo-sightings/workspace/file?filename=nuforc_reports.json

# %%
# Use pandas and SQLAlchemy to extract data
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import datetime

# %%
# Establish path for extracting UFO json file
json_path = "nuforc_reports.json"

# %%
# Extract UFO json data into pandas dataframe using above path
ufo_df = pd.read_json(json_path, lines=True)
ufo_df.head()
# Out:
#                                                 text  \
# 0  My wife was driving southeast on a fairly popu...
# 1  I think that I may caught a UFO on the NBC Nig...
# 2  I woke up late in the afternoon 3:30-4pm.  I w...
# 3  I was driving towards the intersection of fall...
# 4  In Peoria, Arizona, I saw a cigar shaped craft...
#
#                                                stats       date_time  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...  12/12/19 18:43
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...   3/22/19 18:30
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...      April01.19
# 3  Occurred : 4/17/2019 02:00  (Entered as : 04-1...   4/17/19 02:00
# 4  Occurred : 3/15/2009 18:00  (Entered as : 03/1...   3/15/09 18:00
#
#                                          report_link  \
# 0  http://www.nuforc.org/webreports/151/S151739.html
# 1  http://www.nuforc.org/webreports/145/S145297.html
# 2  http://www.nuforc.org/webreports/145/S145556.html
# 3  http://www.nuforc.org/webreports/145/S145697.html
# 4  http://www.nuforc.org/webreports/145/S145723.html
#
#                          city state     shape     duration  \
# 0                     Chester    VA     Light    5 seconds
# 1                  Rocky Hill    CT    Circle  3-5 seconds
# 2                        None  None      None         None
# 3  Ottawa (Carleton) (Canada)    ON  Teardrop   10 seconds
# 4                      Peoria    NY     Cigar    2 minutes
#
#                                              summary    posted
# 0  My wife was driving southeast on a fairly popu...  12/22/19
# 1  I think that I may caught a UFO on the NBC Nig...   3/29/19
# 2  I woke up late in the afternoon 3:30-4pm. I we...   4/12/19
# 3  I was driving towards the intersection of fall...   4/18/19
# 4  In Peoria Arizona, I saw a cigar shaped craft ...   4/18/19

# %% [markdown]
# # Clean UFO Data

# %%
new_ufo_df = ufo_df

#Remove any data rows that have any empty values
new_ufo_df.dropna(how="any", inplace=True)
new_ufo_df = new_ufo_df.fillna("", inplace=False)

#create new date column to rearrange

new_ufo_df['Updated Date'] = new_ufo_df['date_time']
new_ufo_df['Updated Date'] = new_ufo_df['Updated Date'].map(lambda x: str(x)[:-6])

new_ufo_df
# Out:
#                                                     text  \
# 0      My wife was driving southeast on a fairly popu...
# 1      I think that I may caught a UFO on the NBC Nig...
# 3      I was driving towards the intersection of fall...
# 4      In Peoria, Arizona, I saw a cigar shaped craft...
# 5      The object has flashing lights that are green,...
# ...                                                  ...
# 88120  4 lights in formation over Tempe appear while ...
# 88121  2 bright star like lights in the NNW sky two b...
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...
# 88123  Witnessed an orange, slow moving light. Was lo...
# 88124  Glowing lights in formation  just south of San...
#
#                                                    stats       date_time  \
# 0      Occurred : 12/12/2019 18:43  (Entered as : 12/...  12/12/19 18:43
# 1      Occurred : 3/22/2019 18:30  (Entered as : 03/2...   3/22/19 18:30
# 3      Occurred : 4/17/2019 02:00  (Entered as : 04-1...   4/17/19 02:00
# 4      Occurred : 3/15/2009 18:00  (Entered as : 03/1...   3/15/09 18:00
# 5      Occurred : 4/2/2019 20:25  (Entered as : 04/02...    4/2/19 20:25
# ...                                                  ...             ...
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...   10/2/19 20:00
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...   10/2/19 20:00
# 88122  Occurred : 10/2/2019 20:03  (Entered as : 10/0...   10/2/19 20:03
# 88123  Occurred : 10/2/2019 22:00  (Entered as : 10/0...   10/2/19 22:00
# 88124  Occurred : 10/2/2019 22:00  (Entered as : 10-0...   10/2/19 22:00
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 4      http://www.nuforc.org/webreports/145/S145723.html
# 5      http://www.nuforc.org/webreports/145/S145476.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                              city state      shape     duration  \
# 0                         Chester    VA      Light    5 seconds
# 1                      Rocky Hill    CT     Circle  3-5 seconds
# 3      Ottawa (Carleton) (Canada)    ON   Teardrop   10 seconds
# 4                          Peoria    NY      Cigar    2 minutes
# 5                      Kirbyville    TX       Disk   15 minutes
# ...                           ...   ...        ...          ...
# 88120                       Tempe    AZ  Formation    3 minutes
# 88121                     Bolivar    MO      Light   20 seconds
# 88122                  North Port    FL  Formation   20 seconds
# 88123              Black Mountain    NC   Fireball    2 minutes
# 88124                Marin County    CA     Sphere    3 minutes
#
#                                                  summary    posted  \
# 0      My wife was driving southeast on a fairly popu...  12/22/19
# 1      I think that I may caught a UFO on the NBC Nig...   3/29/19
# 3      I was driving towards the intersection of fall...   4/18/19
# 4      In Peoria Arizona, I saw a cigar shaped craft ...   4/18/19
# 5      The object has flashing lights that are green,...    4/8/19
# ...                                                  ...       ...
# 88120  4 lights in formation over Tempe appear while ...   10/4/19
# 88121  2 bright star like lights in the NNW skys,  ((...   10/4/19
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...   10/4/19
# 88123  Witnessed an orange, slow moving light. Was lo...   10/4/19
# 88124  Glowing lights in formation  just south of San...   10/4/19
#
#       Updated Date
# 0         12/12/19
# 1          3/22/19
# 3          4/17/19
# 4          3/15/09
# 5           4/2/19
# ...            ...
# 88120      10/2/19
# 88121      10/2/19
# 88122      10/2/19
# 88123      10/2/19
# 88124      10/2/19
#
# [78706 rows x 11 columns]

# %%
#cleans more by removing non-fulldate entries
#new_ufo_df[new_ufo_df['Updated Date'].apply(lambda x: len(x) < 6)]
ufo_df_2 = new_ufo_df[new_ufo_df['Updated Date'].map(len) > 5]
ufo_df_3 = ufo_df_2[~ufo_df_2['Updated Date'].str.contains("-")]
# ufo_df_4 = ufo_df_3[ufo_df_3['Updated Date'].map(len) > 5]

ufo_df_3
# Out:
#                                                     text  \
# 0      My wife was driving southeast on a fairly popu...
# 1      I think that I may caught a UFO on the NBC Nig...
# 3      I was driving towards the intersection of fall...
# 4      In Peoria, Arizona, I saw a cigar shaped craft...
# 5      The object has flashing lights that are green,...
# ...                                                  ...
# 88120  4 lights in formation over Tempe appear while ...
# 88121  2 bright star like lights in the NNW sky two b...
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...
# 88123  Witnessed an orange, slow moving light. Was lo...
# 88124  Glowing lights in formation  just south of San...
#
#                                                    stats       date_time  \
# 0      Occurred : 12/12/2019 18:43  (Entered as : 12/...  12/12/19 18:43
# 1      Occurred : 3/22/2019 18:30  (Entered as : 03/2...   3/22/19 18:30
# 3      Occurred : 4/17/2019 02:00  (Entered as : 04-1...   4/17/19 02:00
# 4      Occurred : 3/15/2009 18:00  (Entered as : 03/1...   3/15/09 18:00
# 5      Occurred : 4/2/2019 20:25  (Entered as : 04/02...    4/2/19 20:25
# ...                                                  ...             ...
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...   10/2/19 20:00
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...   10/2/19 20:00
# 88122  Occurred : 10/2/2019 20:03  (Entered as : 10/0...   10/2/19 20:03
# 88123  Occurred : 10/2/2019 22:00  (Entered as : 10/0...   10/2/19 22:00
# 88124  Occurred : 10/2/2019 22:00  (Entered as : 10-0...   10/2/19 22:00
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 4      http://www.nuforc.org/webreports/145/S145723.html
# 5      http://www.nuforc.org/webreports/145/S145476.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                              city state      shape     duration  \
# 0                         Chester    VA      Light    5 seconds
# 1                      Rocky Hill    CT     Circle  3-5 seconds
# 3      Ottawa (Carleton) (Canada)    ON   Teardrop   10 seconds
# 4                          Peoria    NY      Cigar    2 minutes
# 5                      Kirbyville    TX       Disk   15 minutes
# ...                           ...   ...        ...          ...
# 88120                       Tempe    AZ  Formation    3 minutes
# 88121                     Bolivar    MO      Light   20 seconds
# 88122                  North Port    FL  Formation   20 seconds
# 88123              Black Mountain    NC   Fireball    2 minutes
# 88124                Marin County    CA     Sphere    3 minutes
#
#                                                  summary    posted  \
# 0      My wife was driving southeast on a fairly popu...  12/22/19
# 1      I think that I may caught a UFO on the NBC Nig...   3/29/19
# 3      I was driving towards the intersection of fall...   4/18/19
# 4      In Peoria Arizona, I saw a cigar shaped craft ...   4/18/19
# 5      The object has flashing lights that are green,...    4/8/19
# ...                                                  ...       ...
# 88120  4 lights in formation over Tempe appear while ...   10/4/19
# 88121  2 bright star like lights in the NNW skys,  ((...   10/4/19
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...   10/4/19
# 88123  Witnessed an orange, slow moving light. Was lo...   10/4/19
# 88124  Glowing lights in formation  just south of San...   10/4/19
#
#       Updated Date
# 0         12/12/19
# 1          3/22/19
# 3          4/17/19
# 4          3/15/09
# 5           4/2/19
# ...            ...
# 88120      10/2/19
# 88121      10/2/19
# 88122      10/2/19
# 88123      10/2/19
# 88124      10/2/19
#
# [78070 rows x 11 columns]

# %%
#update new date column so that it is in yyyy-mm-dd form
date_list = ufo_df_3['Updated Date'].tolist()
date_list_length = len(date_list)
new_date_list = list()
i=0
while i < (300):
    string = date_list[i]
    string.split('/')
    month = string.split('/')[0]
    day = string.split('/')[1]
    year = string.split('/')[2]
    newstr = []

    if int(year) > 21:
        newstr = "19" + year + "-" + month + "-" + day
    else :
        newstr = "20" + year + "-" + month + "-" + day
        
    add = newstr
    new_date_list.insert(i, add)
    i = i+1
    
str_new_date_list = str(new_date_list)[1:-1] 
print(new_date_list)
# Out:
# ['2019-12-12', '2019-3-22', '2019-4-17', '2009-3-15', '2019-4-2', '2019-5-1', '2019-4-10', '1973-7-14', '2019-6-18', '2019-6-12', '2019-6-11', '2018-6-15', '1999-8-15', '1975-7-17', '2019-8-17', '2019-8-14', '2019-8-9', '2019-8-9', '2019-8-6', '2019-8-5', '2019-8-3', '2019-8-1', '2019-7-29', '2019-6-27', '2015-6-15', '2001-9-11', '1979-7-15', '1965-8-20', '1936-7-15', '1947-7-15', '1951-1-20', '1952-6-10', '1955-8-8', '1959-8-1', '1960-7-1', '1960-8-1', '1962-9-4', '1964-1-10', '1965-5-1', '1966-8-1', '1967-9-20', '1968-6-15', '1968-6-15', '1968-6-20', '1968-8-10', '1969-6-1', '1969-6-1', '1969-7-27', '1970-7-1', '1970-7-15', '1970-7-22', '1971